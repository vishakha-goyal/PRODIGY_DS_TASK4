# %%
import nltk

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Load the dataset
df = pd.read_csv("twitter_training.csv")

# %%
# Load the dataset
dff = pd.read_csv("twitter_validation.csv")

# %%
# Preprocess text data (if needed)
# You might need to handle missing values, remove special characters, etc.

# Initialize Sentiment Intensity Analyzer
sia = SentimentIntensityAnalyzer()

# %%
# Perform sentiment analysis and store the results
df['A'] = df['B'].apply(lambda x: sia.polarity_scores(x)['compound'])

# %%
dff.columns
# Out:
# Index(['P', 'Q', 'R', 'S'], dtype='object')

# %%
df
# Out:
#          A            B         C
# 0      0.0  Borderlands  Positive  \
# 1      0.0  Borderlands  Positive
# 2      0.0  Borderlands  Positive
# 3      0.0  Borderlands  Positive
# 4      0.0  Borderlands  Positive
# ...    ...          ...       ...
# 74677  0.0       Nvidia  Positive
# 74678  0.0       Nvidia  Positive
# 74679  0.0       Nvidia  Positive
# 74680  0.0       Nvidia  Positive
# 74681  0.0       Nvidia  Positive
#
#                                                       D
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
# Load the dataset
dff = pd.read_csv("twitter_validation.csv")

# Drop rows with missing values
dff.dropna(inplace=True)

# Drop irrelevant columns (if any)
# Example: df.drop(columns=['irrelevant_column'], inplace=True)

# Preprocess text data
# Example: Convert text to lowercase, remove special characters, etc.
# df['text'] = df['text'].str.lower()

# Display the cleaned DataFrame
print(dff.head())
# Out:
#       P          Q           R
# 0  3364   Facebook  Irrelevant  \
# 1   352     Amazon     Neutral
# 2  8312  Microsoft    Negative
# 3  4371      CS-GO    Negative
# 4  4433     Google     Neutral
#
#                                                    S
# 0  I mentioned on Facebook that I was struggling ...
# 1  BBC News - Amazon boss Jeff Bezos rejects clai...
# 2  @Microsoft Why do I pay for WORD when it funct...
# 3  CSGO matchmaking is so full of closet hacking,...
# 4  Now the President is slapping Americans in the...

# %%
# Analyze sentiment distribution
sentiment_counts = df['A'].value_counts(normalize=True)

# %%
# Load the dataset
df = pd.read_csv("twitter_training.csv")

# Drop rows with missing values
df.dropna(inplace=True)

# Drop irrelevant columns (if any)
# Example: df.drop(columns=['irrelevant_column'], inplace=True)

# Preprocess text data
# Example: Convert text to lowercase, remove special characters, etc.
# df['text'] = df['text'].str.lower()

# Display the cleaned DataFrame
print(df.head())
# Out:
#       A            B         C
# 0  2401  Borderlands  Positive  \
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                   D
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
# Visualize sentiment distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette="viridis")
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment Score")
plt.ylabel("Proportion")
plt.show()

# %%
# Categorize sentiment scores into bins
bins = [-1, -0.5, 0, 0.5, 1]
labels = ['Very Negative', 'Negative', 'Neutral', 'Positive']
df['C'] = pd.cut(df['A'], bins=bins, labels=labels)

# %%
# Plot distribution of sentiment categories
plt.figure(figsize=(8, 6))
sns.countplot(x='C', data=df, palette="viridis")
plt.title("Distribution of Sentiment Categories")
plt.xlabel("Sentiment Category")
plt.ylabel("Count")
plt.show()

# %%
import plotly.express as px

# %%
# Create a pie chart of sentiment categories
sentiment_counts = df['B'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', colors=['red', 'orange', 'lightgrey', 'lightgreen','pink','blue','brown','yellow','olive','maroon','teal','indigo'])
plt.title('Proportion of Sentiment Categories')
plt.show()

# %%
# Perform sentiment analysis and store the results
dff['P'] = dff['S'].apply(lambda x: sia.polarity_scores(x)['compound'])

# Create histogram
plt.figure(figsize=(8, 6))
sns.histplot(dff['P'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df.index, df['A'], color='blue', alpha=0.5)
plt.title('Sentiment Scores Scatter Plot')
plt.xlabel('Index')
plt.ylabel('Sentiment Score')
plt.show()

# %%
# Plot sentiment scores over time using a line plot
plt.figure(figsize=(10, 6))
plt.plot(df['B'], df['A'], marker='o', linestyle='-', color='b')
plt.title('Sentiment Trends Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Sentiment Score')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()
